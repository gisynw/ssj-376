# %% [markdown]
# <a href="https://colab.research.google.com/github/gisynw/ssj-302/blob/main/docs/Demo/Week01_Python_Intro.ipynb" target="_blank">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" style="height: 30px;"/>
# </a>
# &nbsp &nbsp
# <a href="./Week01_Python_Intro.ipynb" target="_blank">
#   <img src="https://img.icons8.com/?size=100&id=108635&format=png&color=000000" alt="Download" style="height: 40px;"/>
#  </a>

# %% [markdown]
# ### 1. Install the Visual Studio Code (VS Code)
# Install [Visual Studio Code](https://code.visualstudio.com/)

# %% [markdown]
# ### 2. Install Anaconda
# To install Anaconda, download the installer from the [Anaconda website](https://www.anaconda.com/download). The installer will ask you to accept the license agreement, choose the installation directory.

# %% [markdown]
# ### 3. Select interpreter in VS code
#
# if it is your first time to select interpretr, you need to install two extensions from extensions in the left side bar:
# - Python
# - Jupyter
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)    ![image-4.png](attachment:image-4.png)
#
# #### The Python:Select Interpreter **(Ctrl+Shift+P)** command displays a list of available gloabl environments, conda environments, and virtual environments.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Create a Juputer Notebook
# You can create a Jupyter Notebook by running the __Create: New Jupyter Notebook__ command from the Command Palette **(Ctrl+Shift+P)** or by creating a new .ipynb file in your workspace.
#
# Or, you can select __'File' > 'New File'__

# %% [markdown]
# ### 5. Start your first Jupyter Notebook
# - Developed originally by UC Berkeley's Ferando Perez
# - Contain code & rich text elements
# - Perfect for sharing your analysis with others
# - Gret for sharing your analysis with others

# %% [markdown]
# ### 6. Writing in Markdown
#
# #### 6.1 Change font size
# * In markdown, we talk about headings instead of font size
#    * use # to adjust the size
# # Heading 1
# ## Heading 2
# ### Heading 3
# sentence
#
# #### 6.2 Formtted text
# - Different styling (bold/italic), bulleted lists, etc
# - In Jupyter, we call these text elements __markdown__
#
# Note: when you edit in VS Code, you can open __Auto Save__ under __File__

# %% [markdown]
# #### 6.3 Bold/Italic
# Thi is __bold__ and this is _italic_
#
# #### 6.4 Buid lists
# The asterisk symbol can be used to created bulleted lists as follows (use tabs to indent)
# * Point one
#     * Point two
# * Point Three
#
# #### 6.5 Creating a new line
# Include __two__ spaces at the end of the line
#
# ### 7. Code cells

# %%
print("Hello, python")
# Out:
# Hello, python

# %%
# This is comment: get result of 3+5
3+5
# Out:
# 8

# %% [markdown]
# ### 8. Save your Jupyter Notebook
# You can save your Jupyter Notebook using the keyboard shortcut **(Ctrl+S)** or **File > Save**.

# %% [markdown]
# ### 9. Export your Jupyter Notebook

# %% [markdown]
# You can export a Jupyter Notebook as a Python file (.py), a PDF, or an HTML file. To export, select ... > **Export** on the main toolbar. You're then presented with a dropdown of file format options.

# %% [markdown]
# ---

# %% [markdown]
# ## 10. Virtual environment
#
# ### 10.1 Create a virtual environment in terminal
#
# Right click the Anaconda prompt and __Run as Administrator__ (This step will ensure that your package is installed in _Anaconda/env_ folder)
#
# The  following command creates a __conda environment named np with a Python 3.9 interpreter__
#
# ```bash
# conda create -n np python=3.9
# ```
#
# ### 10.2 Check conda is installed
# ```bash
# conda -V
# ```
# ![image.png](attachment:image.png)
#
# ### 10.3 List virtual environment
# now if you list virgual envionment, you can see the virtual environment that you just create.
# ```bash
# conda env list
# ```
#
# For example, I have three virtual environment: base, arcpu_pro, np
#
# ![image-2.png](attachment:image-2.png)
#
# ### 10.4 Activate virtual environment
# if you virtual environment named as 'np'
# ```bash
# activate np
# ```
# ![image-3.png](attachment:image-3.png)
#
# ### 10.5 Install packages (e.g., numpy)
# ```bash
# conda install numpy
# ```

# %% [markdown]
# ### 11. Delete a no longer needed virtual environment
# For example, delete a virtual environment 'np'
# ```bash
# conda remove -n np --all -y
# ```
